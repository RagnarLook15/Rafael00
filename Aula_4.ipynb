# %% [markdown]
# <a href="https://colab.research.google.com/github/RagnarLook15/Rafael00/blob/main/Aula_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício 5 AulaLP02)

# %%
P = float(input("!Digite valor em polegas:"))
mm = P * 25.4
print(mm)
# Out:
# !Digite valor em polegas:2
# 50.8
